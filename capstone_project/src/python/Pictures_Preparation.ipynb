# %% [markdown]
# # Data preparation : 1c, picture processing

# %% [markdown]
# In this notebook, we store the appartments pictures for the highly rented full AirBnB appartments, then :
#
# - compute the brightness qnd contrast,
# - convert them into greyscale numpy array and reduce its dimensionality,
# - compute the top 5 RGB colours for each picture.
#
# Finally, all those infos are stored into a Dataframe.

# %%
# %matplotlib inline

from os import listdir
from os.path import isfile, join

import matplotlib.pyplot as plt

from pylab import rcParams
import numpy as np
import pandas as pd
from ggplot import *

import scipy
import scipy.misc
import scipy.cluster

from sklearn.decomposition import PCA
from sklearn.preprocessing import scale


from PIL import Image, ImageFilter
import urllib

# %% [markdown]
# ## Create a list of appart ID / picture urls

# %%
df_listing = pd.read_csv('../../data/listing_cleansed.csv')

# %%
df_listing['listings_per_host']=df_listing.groupby(["host_id"])["listing_id"].transform("count")

# %%
df_listing= df_listing[df_listing.availability_90>0]

# %%
df_listing
# Out:
#       listing_id    host_id       host_name  host_since  host_response_time  \
# 0       16682014  110413588           Julia       200.0                 1.0
# 1       15767215   39537907           Andre       733.0                 4.0
# 2         115576     584750            Axel      2267.0                 NaN
# 3        7568544   39056052         Claudia       738.0                 4.0
# 8       16926322   25707959            Anja       933.0                 4.0
# 9       10402942   53565483       Burghardt       568.0                24.0
# 10      10027737   50795723        Victoria       597.0                24.0
# 13      16153479  105373097         Vanessa       242.0                 1.0
# 14      13920566    3351408          Oliver      1799.0                 NaN
# 15      17783667  121453952          Thomas       130.0                 NaN
# 16      16865367  112381310             Uwe       188.0                 1.0
# 17       4604780   23822141  Jens & Annette       984.0                 4.0
# 18        768616    4054647       Cornelius      1726.0                 1.0
# 19      14542554    2227611           Maria      1918.0                24.0
# 23       4119526   21370854          Tobias      1046.0                 4.0
# 25      11381321   59676944           Elena       522.0                 1.0
# 26       5501882   10787910       Christine      1311.0                 4.0
# 27       6295492   30981168         Natalie       839.0                 1.0
# 31      10897967   19266681            Matt      1091.0                 4.0
# 33      17504448  118639204       Ina-Maria       148.0                24.0
# 35       2281634   11652909       Francesca      1278.0                 4.0
# 37         30295     485838         Michele      2305.0                 1.0
# 39      13670601   17952846             Eve      1112.0                 4.0
# 45      16143418   21200871          Daniel      1050.0                 4.0
# 50       1379728    7345295         Marleen      1480.0                 1.0
# 51        306312    1575292   Michel & Anne      2029.0                 1.0
# 54        772854    4057507             Uwe      1726.0                 1.0
# 60       1351684    7334943             Eva      1481.0                24.0
# 64       8280619    2034980          Farina      1945.0                 1.0
# 66        789018    4057507             Uwe      1726.0                 1.0
# ...          ...        ...             ...         ...                 ...
# 9164    17948654   40956895       Katharina       718.0                 1.0
# 9166     1711351    9027357         Heidrun      1402.0                24.0
# 9167    11517189   60709250        Gabriele       515.0                 1.0
# 9168     6420032   33493499          Katrin       803.0                 1.0
# 9169    12743706   69313857        Wolfgang       455.0                 4.0
# 9170      233770    1224097        Bernhard      2128.0                 4.0
# 9171     2876427    9027357         Heidrun      1402.0                24.0
# 9172    10229937   48598844          Astrid       626.0                 1.0
# 9173    12580861   62111409         Martina       506.0                24.0
# 9174    12672130    1584570           Marko      2026.0                 4.0
# 9175    14243709   27658886         Stephan       896.0                 4.0
# 9176     6834476   35803835           Boris       774.0                 1.0
# 9177    10303017   53010959           Karin       572.0                 1.0
# 9178    12323782   66491532          Sabine       474.0                 1.0
# 9179     1442066    7743542       Christian      1462.0                 1.0
# 9183     1130337     915430         Andreas      2185.0                 4.0
# 9184      769334    2953733           Semra      1837.0                 4.0
# 9185    15265341   70148130            Alex       450.0                 4.0
# 9186    16373826   99343137           Manzi       288.0                24.0
# 9187    15766299   64555752          Robert       488.0                 1.0
# 9189    14162415   50217677        Matthias       605.0                 4.0
# 9191     8119489   41792917          Tamara       709.0                48.0
# 9195     5847560    4102719       Stephanie      1721.0                 1.0
# 9196    18093451  124611709         Norbert       112.0                 4.0
# 9197     1400385    1157727           David      2143.0                24.0
# 9198    15777459    2217792       Alexander      1919.0                24.0
# 9199    14586020    1808253             Eva      1979.0                24.0
# 9204     6802462   35562460            Miro       777.0                24.0
# 9205    17913282  121994786           Amana       127.0                 4.0
# 9207     4712991   24354535            Ulli       969.0                24.0
#
#       host_response_rate  host_is_superhost  host_listings_count  \
# 0                  100.0                  0                  3.0
# 1                  100.0                  0                  1.0
# 2                    NaN                  0                  1.0
# 3                  100.0                  0                  1.0
# 8                  100.0                  0                  2.0
# 9                  100.0                  0                  1.0
# 10                  67.0                  0                  1.0
# 13                 100.0                  0                  1.0
# 14                   NaN                  0                  1.0
# 15                   NaN                  0                  1.0
# 16                 100.0                  0                  1.0
# 17                 100.0                  0                  1.0
# 18                 100.0                  1                  2.0
# 19                  50.0                  0                  1.0
# 23                 100.0                  0                  1.0
# 25                 100.0                  0                  2.0
# 26                 100.0                  0                  1.0
# 27                 100.0                  1                  3.0
# 31                 100.0                  0                  1.0
# 33                 100.0                  0                  1.0
# 35                  90.0                  1                  2.0
# 37                 100.0                  0                  4.0
# 39                  90.0                  0                  2.0
# 45                 100.0                  0                  1.0
# 50                 100.0                  0                  2.0
# 51                 100.0                  0                  2.0
# 54                 100.0                  0                  6.0
# 60                 100.0                  0                  1.0
# 64                 100.0                  0                  1.0
# 66                 100.0                  0                  6.0
# ...                  ...                ...                  ...
# 9164               100.0                  0                  1.0
# 9166               100.0                  0                  2.0
# 9167               100.0                  1                  1.0
# 9168               100.0                  0                  1.0
# 9169                90.0                  0                  1.0
# 9170               100.0                  0                  1.0
# 9171               100.0                  0                  2.0
# 9172               100.0                  0                  1.0
# 9173                75.0                  0                  1.0
# 9174               100.0                  0                  1.0
# 9175               100.0                  0                  1.0
# 9176               100.0                  1                  4.0
# 9177               100.0                  0                  1.0
# 9178               100.0                  0                  1.0
# 9179               100.0                  1                  1.0
# 9183                85.0                  0                  1.0
# 9184               100.0                  1                  3.0
# 9185               100.0                  0                  2.0
# 9186                88.0                  0                  1.0
# 9187               100.0                  0                  2.0
# 9189               100.0                  0                  1.0
# 9191                 0.0                  0                  2.0
# 9195               100.0                  0                  2.0
# 9196               100.0                  0                  1.0
# 9197                92.0                  0                  2.0
# 9198                80.0                  0                  1.0
# 9199                80.0                  0                  1.0
# 9204                90.0                  0                  1.0
# 9205                83.0                  0                  1.0
# 9207               100.0                  1                  2.0
#
#       host_has_profile_pic  host_identity_verified        ...          \
# 0                        1                       0        ...
# 1                        1                       0        ...
# 2                        1                       0        ...
# 3                        1                       1        ...
# 8                        1                       1        ...
# 9                        1                       0        ...
# 10                       1                       0        ...
# 13                       1                       0        ...
# 14                       1                       0        ...
# 15                       1                       0        ...
# 16                       1                       0        ...
# 17                       1                       1        ...
# 18                       1                       0        ...
# 19                       1                       1        ...
# 23                       1                       1        ...
# 25                       1                       1        ...
# 26                       1                       1        ...
# 27                       1                       1        ...
# 31                       1                       0        ...
# 33                       1                       0        ...
# 35                       1                       1        ...
# 37                       1                       1        ...
# 39                       1                       0        ...
# 45                       1                       1        ...
# 50                       1                       0        ...
# 51                       1                       1        ...
# 54                       1                       0        ...
# 60                       1                       0        ...
# 64                       1                       1        ...
# 66                       1                       0        ...
# ...                    ...                     ...        ...
# 9164                     1                       1        ...
# 9166                     1                       1        ...
# 9167                     1                       0        ...
# 9168                     1                       0        ...
# 9169                     1                       0        ...
# 9170                     1                       0        ...
# 9171                     1                       1        ...
# 9172                     1                       0        ...
# 9173                     1                       0        ...
# 9174                     1                       1        ...
# 9175                     1                       1        ...
# 9176                     1                       1        ...
# 9177                     1                       0        ...
# 9178                     1                       1        ...
# 9179                     1                       0        ...
# 9183                     1                       1        ...
# 9184                     1                       1        ...
# 9185                     1                       1        ...
# 9186                     1                       0        ...
# 9187                     1                       1        ...
# 9189                     1                       1        ...
# 9191                     1                       0        ...
# 9195                     1                       1        ...
# 9196                     1                       0        ...
# 9197                     1                       0        ...
# 9198                     1                       1        ...
# 9199                     1                       1        ...
# 9204                     1                       1        ...
# 9205                     1                       1        ...
# 9207                     1                       1        ...
#
#       text_experiences_offered  \
# 0                         none
# 1                         none
# 2                         none
# 3                         none
# 8                         none
# 9                         none
# 10                        none
# 13                        none
# 14                        none
# 15                        none
# 16                        none
# 17                        none
# 18                        none
# 19                        none
# 23                        none
# 25                        none
# 26                        none
# 27                        none
# 31                        none
# 33                        none
# 35                        none
# 37                        none
# 39                        none
# 45                        none
# 50                        none
# 51                        none
# 54                        none
# 60                        none
# 64                        none
# 66                        none
# ...                        ...
# 9164                      none
# 9166                      none
# 9167                      none
# 9168                      none
# 9169                      none
# 9170                      none
# 9171                      none
# 9172                      none
# 9173                      none
# 9174                      none
# 9175                      none
# 9176                      none
# 9177                      none
# 9178                      none
# 9179                      none
# 9183                      none
# 9184                      none
# 9185                      none
# 9186                      none
# 9187                      none
# 9189                      none
# 9191                      none
# 9195                      none
# 9196                      none
# 9197                      none
# 9198                      none
# 9199                      none
# 9204                      none
# 9205                      none
# 9207                      none
#
#                              text_neighborhood_overview  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Die Wohnung befindet sich über einem tollen kl...
# 8                                                   NaN
# 9                                                   NaN
# 10    In unmittelbarer Umgebung befinden sich einige...
# 13    Pankow ist ein familienfreundlicher grüner Sta...
# 14                                                  NaN
# 15    Dinner? > Trattoria Pasta Degli Angeli - (URL ...
# 16    Anschluss zur City in 18 Auto min , Anschluss ...
# 17    Pankow ist ein ruhiger grüner Bezirk und trotz...
# 18                                                  NaN
# 19                                                  NaN
# 23    In Prenzlauer Berg you’ll find everything you ...
# 25    Prenlzlauer Berg is a great with many cafes, b...
# 26    The neighborhood is fantastic unless you are l...
# 27    in der Nähe: Kollwitzplatz , Hackesche Höfe, A...
# 31    Fifteen minutes North of Alexanderplatz, Prenz...
# 33                                                  NaN
# 35    The apartment is located in one of the most be...
# 37                                                  NaN
# 39                                                  NaN
# 45    Prenzlauer Berg is known for its picturesque s...
# 50    Helmholtzplatz (2 minutes) and city railway (S...
# 51                                                  NaN
# 54                                                  NaN
# 60                                                  NaN
# 64    Die Wohnung liegt im Herzen des Prenzl Berg mi...
# 66                                                  NaN
# ...                                                 ...
# 9164  Comfy and safe area. Ruhige Bürgerliche Umgebu...
# 9166  Berlin-Marzahn is a part of the Municipality H...
# 9167  Die Gärten der Welt IGA 2017 (ca. 15 Autominut...
# 9168                                                NaN
# 9169                                                NaN
# 9170                                                NaN
# 9171  Berlin-Marzahn is a part of the Municipality H...
# 9172  The neighborhood is quiet, the house is in a o...
# 9173                                                NaN
# 9174  Die Unterkunft liegt in ruhigen Wohngegend .  ...
# 9175                             nature, lakes, silence
# 9176                                                NaN
# 9177  Das Ferienhaus befindet sich in einer ruhigen ...
# 9178  Die Ferienwohnung befindet sich in einer sehr ...
# 9179  Köpenick ist berühmt durch seinen Hauptmann vo...
# 9183                                                NaN
# 9184                                                NaN
# 9185  (Wedding /Reinickendorf) very close to city Ce...
# 9186                                                NaN
# 9187  Quiet neighboorhood. So please respekt that......
# 9189  All the neighbours are always very kind, helpf...
# 9191                                                NaN
# 9195  Reinickendorf is a wonderful part of Berlin. I...
# 9196                                                NaN
# 9197  The apartment is located centrally but also in...
# 9198  Common residential area close to Kienhorstpark...
# 9199  this place is part of the white City - famous ...
# 9204  The immediate vicinity is quiet and green - wi...
# 9205                                                NaN
# 9207  In unmittelbarer Nähe ist alles vorhanden: Sup...
#
#                                              text_notes  \
# 0                                                   NaN
# 1     Bitte beachten Sie, dass in Berlin Gäste  zusä...
# 2                                                   NaN
# 3                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17    Zu Fuß sind drei Supermärkte sowie ein Restaur...
# 18                                                  NaN
# 19                                                  NaN
# 23                                                  NaN
# 25    Please notice that the flat is on the ground f...
# 26    Must Love Cats!!!! Trixie, my 17-year old swee...
# 27    Check-In: 15.00 - 20.00 Check out : 10.00 Rein...
# 31    Please note that this space is on the fifth fl...
# 33                                                  NaN
# 35                                                  NaN
# 37    "Zweckentfremdungsgesetz" Since May 1st,  a ne...
# 39                                                  NaN
# 45    Since this is my private space, please respect...
# 50                      Rauchen bitte nur in der Küche.
# 51    Other Things to Note CITY TAX  Since the 1st o...
# 54                                                  NaN
# 60                                                  NaN
# 64                                                  NaN
# 66                                                  NaN
# ...                                                 ...
# 9164  Smoking is forbidden, No pets. Childs are allo...
# 9166  In Berlin an accommodation tax of 5% is charge...
# 9167  Das Objekt ist im Außenbereich videoüberwacht....
# 9168                                                NaN
# 9169                                                NaN
# 9170                                                NaN
# 9171  In Berlin an accommodation tax of 5% is charge...
# 9172  You will find cleaning products, dishwasher de...
# 9173                        4. Gast auf Anfrage möglich
# 9174  Das Haus liegt in einer ruhigen Wohngegend und...
# 9175                                                NaN
# 9176                       Nichtraucher - Ferienwohnung
# 9177                                                NaN
# 9178  Die Stadtverwaltung von Berlin erhebt eine Übe...
# 9179   Gute Parkmöglichkeit für den PKW 40 Meter um ...
# 9183                                                NaN
# 9184                                                NaN
# 9185  I can advice you where to go in Berlin and wha...
# 9186                                                NaN
# 9187  Ihr könnt alles benutzen (Wasserkocher, Kühlsc...
# 9189  The apartment is located near Airport Tegel, s...
# 9191                                                NaN
# 9195  If you would like to rent my apartment for an ...
# 9196                                                NaN
# 9197                                                NaN
# 9198  Fresh towels and linen as well as a hair dryer...
# 9199  As we are quiet close to Tegel, you may hear a...
# 9204  The area gets some noise from the Tegel airpor...
# 9205  Bitte nicht in der Wohnung rauchen und bitte k...
# 9207  Bitte beachte, dass das Mitbringen oder Halten...
#
#                                            text_transit  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Sehr gute Anbindung an den öffentlichen Nahver...
# 8                                                   NaN
# 9     Haltestellen der Straßenbahnlinie M1 und der B...
# 10    M1 Straßenbahn (fährt direkt bis zur Friedrich...
# 13    Vom Apartment fahren Sie in etwa 20 Minuten zu...
# 14                                                  NaN
# 15    Tram  next station 2 minutes is Heinrich-Böll-...
# 16    Das Parken ist frei bei uns. Die Strassenbahn ...
# 17    Alle öffentlichen Verkehrsmittel sind gut erre...
# 18    The nearest train station and tram station is ...
# 19    S-Bahn Prenzlauer Allee (Ringbahn S41/24, dire...
# 23    Tram (M2, Fröbelstraße) and railway (S41/42, S...
# 25    You can reach the apartment with: S-Bahn lines...
# 26    Super easy to get to anywhere in Berlin. Right...
# 27    S-Bahn, Straßenbahn, Bus Stationen, Taxistand ...
# 31    Five minute walk to Prenzlauer Allee Ring Bahn...
# 33                                                  NaN
# 35    Around my place you can have delicious food an...
# 37                                                  NaN
# 39                                                  NaN
# 45    Alexanderplatz (Mitte) 10 min. by tram. U-Bhf ...
# 50    Tram M2 (streetcar): Fröbelstr. (6 min.)  S-Ba...
# 51                                                  NaN
# 54                                                  NaN
# 60                                                  NaN
# 64    Die M1, M10, U2,M12 und S Bahn sind in 5 mins ...
# 66                                                  NaN
# ...                                                 ...
# 9164  If you need some further informations or tipps...
# 9166  The City is about 16 km away and easily reache...
# 9167  S-Bahn, Bus und Tram sind in der Nähe. Im Umkr...
# 9168  Die Unterkunft befindet sich nur wenige Gehmin...
# 9169                                                NaN
# 9170                                                NaN
# 9171  The City is about 16 km away and easily reache...
# 9172  Parking is free of charge in front of the hous...
# 9173  Die Innenstadt ist etwa 16 km entfernt und sch...
# 9174  Die nächste Straßenbahn- und Bushaltestelle si...
# 9175   private parking inlusive,  3min to train station
# 9176  Der öffentliche Nahverkehr befindet sich in un...
# 9177  In 7 Gehminuten ist die Straßenbahnlinie 62 un...
# 9178  In nur 7 Gehminuten erreicht man die S-Bahn, d...
# 9179  Die Tram 62 ist 200 Meter vom Objekt entfernt....
# 9183                                                NaN
# 9184  U8 Residenzstr. zu Alexanderplatz via Gesundbr...
# 9185  It has Access to awesome public communications...
# 9186                                                NaN
# 9187  Many busses, U8 within walking distancce (3 mi...
# 9189  Closest subway station is called "Residenzstra...
# 9191                                                NaN
# 9195  The U8 is only a 5 minute walk away and the S2...
# 9196  - 5 min. from Paracelsus Bad (U8) underground ...
# 9197  Two of the main subway lines are walking dista...
# 9198  U8 - Lindauer Allee 150 meters distance. Bus s...
# 9199  Sehr gute Anbindung (U8 Richt Alex, Ringbahn, ...
# 9204  The area (as the whole Berlin) is extremely bi...
# 9205                                                NaN
# 9207  unser Haus ist in Berlin-Wittenau, ruhig geleg...
#
#                                             text_access  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Ihr dürft die komplette Wohnung  einschließlic...
# 8                                                   NaN
# 9                                                   NaN
# 10                 Ihr habt zur gesamten Wohnung Zugang
# 13                                                  NaN
# 14    You are able to use the Home-Cinema System, Wi...
# 15                                                  NaN
# 16    Küche befinden sich alle erforderlichen Hausha...
# 17    Die Wohnung verfügt über eine eigene Küche und...
# 18    Iron and ironing board, well equipped kitchen ...
# 19                                                  NaN
# 23    Entering the flat, you get directly into our b...
# 25    You have a small kitchen with all need equipme...
# 26                                         Full access.
# 27    Die Gäste können  auf einen  WLAN/Internet Zug...
# 31    Full access: Kitchen (gas stove! dishwasher), ...
# 33                                                  NaN
# 35                               Fully equipped kitchen
# 37    In the apartment you have two large rooms of t...
# 39                                                  NaN
# 45                                                  NaN
# 50    - Wi-Fi  - cable TV - dishwasher - kitchen ute...
# 51                                                  NaN
# 54                                                  NaN
# 60                                                  NaN
# 64                                                  NaN
# 66                                                  NaN
# ...                                                 ...
# 9164                                    Gesamte Wohnung
# 9166  The flat in the holiday house is available ful...
# 9167  Der Bungalow verfügt über einen vollständigen ...
# 9168                                                NaN
# 9169                                                NaN
# 9170                                                NaN
# 9171        The apartment is available fully available.
# 9172                     Separate entrance at all times
# 9173  Die gesamte Wohnung kann eigenständig genutzt ...
# 9174                             Zugang zum Garten  :-)
# 9175  complete house, privat bedroom upstairs and pr...
# 9176  Die Ferienwohnung hat mit extra Eingang, einen...
# 9177  Es gibt einen eigenen Zugang zum Ferienhaus. D...
# 9178                                                NaN
# 9179  Ein Grill, ein Feuerkorb,2 Fahrräder,2 Liegen ...
# 9183                                                NaN
# 9184  During Christmas and New Year you pay for 1 ro...
# 9185  The Apartment is fully furnished and the guest...
# 9186                                                NaN
# 9187                         You will get your own Key.
# 9189                                                NaN
# 9191                                                NaN
# 9195  You can relax in the spacious living room, whi...
# 9196  The apartment belongs to you completely. Livin...
# 9197  The rooms are equipped beautifully and our gue...
# 9198  Fast internet via WiFi. Besides, a parking lot...
# 9199  You have access to all areas, accept to my bed...
# 9204  You will have access to the entire apartment, ...
# 9205                                                NaN
# 9207  W-LAN mit 100MBit/s ist kostenlos verfügbar.  ...
#
#                                        text_interaction  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Während Deines Aufenthaltes in unserer Wohnung...
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 13                                                  NaN
# 14    You can reach me via Mobile-Phone if you have ...
# 15                                                  NaN
# 16                                                  NaN
# 17    Die Wohnung befindet sich im Dachgeschoss des ...
# 18    During your stay, I am always available for yo...
# 19    For questions or any advices I will be availab...
# 23    We obviously won’t be in the apartment as long...
# 25    I have a key box for Check-In and Check-Out. B...
# 26    I leave lots of recommendations for the neighb...
# 27    Kontakt jederzeit telefonisch (auch per SMS) o...
# 31    When we're not at home we're usually traveling...
# 33                                                  NaN
# 35    I will be not in the apartment during my guest...
# 37                                                  NaN
# 39                                                  NaN
# 45                                                  NaN
# 50    In this version of the booking you've got the ...
# 51                                                  NaN
# 54                                                  NaN
# 60                                                  NaN
# 64                                                  NaN
# 66                                                  NaN
# ...                                                 ...
# 9164                Bei Fragen stehe ich zur Verfügung.
# 9166                                                NaN
# 9167  Bei Fragen und Problemen vor Ort stehen wir eu...
# 9168  Unsere Gäste können uns während ihres Aufentha...
# 9169                                                NaN
# 9170                                                NaN
# 9171                                                NaN
# 9172  We are happy to advise our guests about Berlin...
# 9173  Wir wohnen in der Wohnung im Obergeschoss, sin...
# 9174  Gerne stehen wir allen unseren Gästen mit Tipp...
# 9175  we'll be on vacation, so we're not in town thi...
# 9176                  Wir wohnen mit auf dem Grundstück
# 9177  Während des Aufenthalts wird jemand als Anspre...
# 9178  Gerne stehen wir als Ansprechpartner zur Verfü...
# 9179  Die Gäste haben Ihr eigenes Haus,Ihren separat...
# 9183                                                NaN
# 9184  Ich bin stets für Euch da wenn ihr mich währen...
# 9185                                                NaN
# 9186                                                NaN
# 9187  My flatmate and I can help you with anything y...
# 9189  If there's anything else you need, feel free t...
# 9191                                                NaN
# 9195  I've lived in Berlin for 5 years and I'll happ...
# 9196  I live in another apartment, so I would only p...
# 9197  If possible, I take care of handing the keys o...
# 9198  We are available via phone/internet, if questi...
# 9199           You can contact me via telefone any time
# 9204  I will personally meet the guests and show the...
# 9205                                                NaN
# 9207  Wir (Uli und Peter) wohnen im Haus und stehen ...
#
#                                        text_house_rules  \
# 0                                                   NaN
# 1                                                   NaN
# 2     non smoking area! Garden is usable for guests....
# 3     Rücksichtsvoller Umgang mit allen Sachen: so, ...
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16    Rauchen ist nur außerhalb der Wohnung in vorge...
# 17    Bitte nur auf dem Balkon rauchen.  Haustiere s...
# 18    SMOKING Non smoking apartment, but allowed on ...
# 19                                                  NaN
# 23    Non-smoking apartment: no smoking anywhere ins...
# 25    Please wash your dishes and though away the ga...
# 26    Smokers are welcome on the balcony or in back ...
# 27    es wird um ein gepflegtes Benehmen gebeten und...
# 31    1. Be courteous to the neighbours: keep BBQ fl...
# 33                                                  NaN
# 35    Please: - Do not use the internet provided at ...
# 37    How to enter the apartment Use the key to open...
# 39                                                  NaN
# 45                                                  NaN
# 50    No shoes in the apartment! There are house sho...
# 51    - be friendly to the neighbors - No Party - No...
# 54                                                  NaN
# 60                                                  NaN
# 64    I live in a home full of families, so no exces...
# 66                                                  NaN
# ...                                                 ...
# 9164                                                NaN
# 9166  - Friendly and respectful behavior. - Waste Pl...
# 9167  Im Bungalow besteht striktes  Rauchverbot, nur...
# 9168  Für unsere Raucher unter den Gästen haben wir ...
# 9169                                                NaN
# 9170                                                NaN
# 9171  - Friendly and respectful behavior. - Please s...
# 9172  Bitte keine unerlaubten Internet-Inhalte herun...
# 9173  Das Rauchen in der Wohnung ist nichts gestatte...
# 9174  Im Haus besteht generelles Rauchverbot und wir...
# 9175  please do not invite all your new friends in B...
# 9176                  Freude - Zufriedenheit - Harmonie
# 9177                                                NaN
# 9178  Übernachtungssteuer in Höhe von 5% des Übernac...
# 9179  Das Rauchen im Haus und Haustiere sind nicht g...
# 9183                                                NaN
# 9184                                               ....
# 9185  You can smoke on the balcony ,  and please don...
# 9186                                                NaN
# 9187  Common Sense ;) + keine Schlüsselweitergabe, n...
# 9189  - Smoking only on the balcony - No parties, no...
# 9191  Keine privaten Parties ... Keine laute muzik n...
# 9195                    Only available for non-smokers.
# 9196                                                NaN
# 9197                Smoking only allowed at the balcony
# 9198  Bitte nicht rauchen und die Nachbarn respektie...
# 9199  - bitte keine Schuhe im Haus, es gibt dicke So...
# 9204  This is my private house, so please no smoking...
# 9205      - Nicht mit Schuhen in der Wohnung rumlaufen.
# 9207  Es ist ein Nichtraucher Apartment. Im hauseige...
#
#                                         text_host_about  text_language  \
# 0                                                   NaN             de
# 1                                                   NaN             de
# 2     I love my wife and three kids, my little dog (...             en
# 3     Ich war früher eine Weltenbummlerin und immer ...             de
# 8                                                   NaN             de
# 9                                                   NaN             de
# 10                                                  NaN             de
# 13                                                  NaN             de
# 14    Wir sind eine 7-köpfige Familie aus Berlin und...             en
# 15                                                  NaN             en
# 16                                                  NaN             de
# 17    Meine Familie und ich sind nette freundliche h...             de
# 18    Hallo. Als Gastgeber ist es mir besonders wich...             en
# 19                                                  NaN             en
# 23                                                  NaN             en
# 25                                                  NaN             en
# 26    Hi, I'm Christine. I grew up in Miami and move...             en
# 27    Ich lebe  und arbeite seit 2001 in Berlin und ...             de
# 31    A Canadian expat living in Berlin, I like to t...             en
# 33                                                  NaN             de
# 35    I am 36 years old and I have a full time job t...             en
# 37    I am a free-lance journalist. I work for sever...             en
# 39                    Kreativ Chaotisch und sehr lustig             de
# 45                                                  NaN             en
# 50    Liebe das Leben, reisen und Yoga. --- I love l...             en
# 51                  We are a original Berliner Couple !             en
# 54    Seit 7 Jahren vermiete ich in Berlin Ferienwoh...             de
# 60    Hello, we are a "filmmaker family", live in Be...             en
# 64    Happy soul being fortunate to combine work in ...             en
# 66    Seit 7 Jahren vermiete ich in Berlin Ferienwoh...             de
# ...                                                 ...            ...
# 9164                                                NaN             de
# 9166  Wir freuen uns darauf Sie ganz herzlichst in u...             en
# 9167  Ich bin Rentnerin, die mit ihrem Ehemann - ebe...             de
# 9168                                                NaN             de
# 9169                                                NaN             de
# 9170  Hallo! Ich würde mich freuen durch Airbnb viel...             en
# 9171  Wir freuen uns darauf Sie ganz herzlichst in u...             en
# 9172  Mit Welterfahrung, Toleranz und Freude am Lebe...             en
# 9173                                                NaN             de
# 9174  Hallo, meine Familie und ich leben in Berlin.\...             de
# 9175                 From now on with toddler and Baby              en
# 9176  Ich interessiere mich für Kunst, Kultur und Ar...             de
# 9177                                                NaN             de
# 9178                                                NaN             de
# 9179  Ich bin Rentner und verheiratet.Wir lieben die...             de
# 9183                       travel-experienced, friendly             en
# 9184  I love to travel and to welcome guests. Be my ...             en
# 9185    I'm Alex org from Poland and living in Germany              en
# 9186                                                NaN             en
# 9187  Privat mache ich gerne Sport, habe viel für gu...             en
# 9189                                                NaN             en
# 9191                                                NaN             de
# 9195  Hi there! I love Airbnb. I enjoy meeting and h...             en
# 9196                                                NaN             en
# 9197    I love getting around and exploring new things.             en
# 9198  I am a theoretical physicist working currently...             en
# 9199  Hi everybody, Im Eva from Germany and I looove...             en
# 9204  I'm an American, originally from Chicago, livi...             en
# 9205  Ich bin 22 Jahre alt und studiere Jura im 8. S...             de
# 9207                                                NaN             de
#
#       listings_per_host
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 8                     2
# 9                     1
# 10                    1
# 13                    1
# 14                    1
# 15                    1
# 16                    1
# 17                    1
# 18                    1
# 19                    1
# 23                    1
# 25                    2
# 26                    1
# 27                    2
# 31                    1
# 33                    1
# 35                    1
# 37                    4
# 39                    1
# 45                    1
# 50                    1
# 51                    2
# 54                    5
# 60                    1
# 64                    1
# 66                    5
# ...                 ...
# 9164                  1
# 9166                  2
# 9167                  1
# 9168                  1
# 9169                  1
# 9170                  1
# 9171                  2
# 9172                  1
# 9173                  1
# 9174                  1
# 9175                  1
# 9176                  1
# 9177                  1
# 9178                  1
# 9179                  1
# 9183                  1
# 9184                  1
# 9185                  2
# 9186                  1
# 9187                  1
# 9189                  1
# 9191                  1
# 9195                  1
# 9196                  1
# 9197                  1
# 9198                  1
# 9199                  1
# 9204                  1
# 9205                  1
# 9207                  1
#
# [4887 rows x 221 columns]

# %%
df_listing_all = pd.read_csv('../../data/insideAirBnB/listings.csv')

col_url = [col for col in df_listing_all.columns if 'url' in col]
col_reviews = [col for col in df_listing.columns if 'review' in col]

df_listing_all[df_listing_all.id==4106583][col_url].transpose()
# Out:
#                                                                 18254
# listing_url                      https://www.airbnb.com/rooms/4106583
# thumbnail_url       https://a0.muscache.com/im/pictures/52427497/3...
# medium_url          https://a0.muscache.com/im/pictures/52427497/3...
# picture_url         https://a0.muscache.com/im/pictures/52427497/3...
# xl_picture_url      https://a0.muscache.com/im/pictures/52427497/3...
# host_url                   https://www.airbnb.com/users/show/20998252
# host_thumbnail_url  https://a0.muscache.com/im/users/20998252/prof...
# host_picture_url    https://a0.muscache.com/im/users/20998252/prof...

# %%
df_listing_all[df_listing_all.id==4106583][col_url].xl_picture_url.values
# Out:
# array([ 'https://a0.muscache.com/im/pictures/52427497/3b3b7391_original.jpg?aki_policy=x_large'], dtype=object)

# %%
print df_listing.shape
print df_listing_all.shape
# Out:
# (4887, 221)
# (20576, 95)

# %%
df_pictures_url = pd.merge(df_listing[['listing_id']], df_listing_all[['id']+col_url], left_on='listing_id',right_on='id')

# %%
df_pictures_url.drop('id',inplace=True,axis=1)

# %%
df_pictures_url.to_csv('../../data/listings_active_pictures_url.csv')

# %% [markdown]
# ## Scrap all appartment pictures for high rented flats

# %%
def scrap_pictures(id,url):
   
    try:
        urllib.urlretrieve(url, "../../data/pictures/"+  str(id )+".jpg")
    except Exception as e:
        print e
        print "cannot scrap {}".format(url)

# %%
def check_pictures_files_is_local(list_url):
    local_files =  [f for f in listdir('../../data/pictures') if isfile(join('../../data/pictures', f))]
    local_files =[int(f.split(".")[0]) for f in local_files]
    
    server_files = [f for f in list_url if f[0] not in local_files]
    
    
    return server_files

# %%
list_url = df_pictures_url[['listing_id','picture_url']].sort_values(by='listing_id').values.tolist()
list_url = check_pictures_files_is_local(list_url)

# %%
len(list_url)
# Out:
# 0

# %%
for url in list_url:
    scrap_pictures(url[0],url[1])

# %% [markdown]
# ## Extract pictures features

# %%
#Pictures paramters
SIZE = (64, 64)
FORMAT = 'L'

# %% [markdown]
# ### Compute contrast and brightness for each picture

# %%
def compute_contrast_and_brightness(pic_file) :
    pic_id = pic_file.split('.')[0]
    img = Image.open('../../data/pictures/'+pic_file).convert('RGB')
    img = img.resize(SIZE, Image.ANTIALIAS) 
    img.load()
    data = np.asarray(img, dtype="int32" )
    R = data[:,:,0]
    G = data[:,:,1]
    B = data[:,:,2]
    LuminanceA = (0.2126*R) + (0.7152*G) + (0.0722*B)
    
    return np.asarray((pic_id,R.std(),G.std(),B.std(),LuminanceA.mean(),LuminanceA.std()),dtype="int32")

# %%
def create_contrast_brightness_matrix():
    all_pics =  [f for f in listdir('../../data/pictures') if isfile(join('../../data/pictures', f))]
    
    i=0
    for pic_file in all_pics:
        
        try: 
            npdata = compute_contrast_and_brightness(pic_file)
        except Exception as e:
            print "{0} for {1}".format(e,pic_file)
            continue
               
        if i==0:
            npdata_all = npdata
            i=1
        else :
            npdata_all = np.vstack((npdata_all,npdata))
        
    return npdata_all

# %%
df_contrasts_brightness = pd.DataFrame(create_contrast_brightness_matrix())
# Out:
# cannot identify image file '../../data/pictures/15959427.jpg' for 15959427.jpg
# cannot identify image file '../../data/pictures/16543634.jpg' for 16543634.jpg
# image file is truncated (0 bytes not processed) for 5284687.jpg

# %%
df_contrasts_brightness.columns =['listing_id','R_contrast','G_contrast','B_contrast','Brightness_mean','Brightness_std']

# %%
df_contrasts_brightness.describe()
# Out:
#          listing_id   R_contrast   G_contrast   B_contrast  Brightness_mean  \
# count  4.884000e+03  4884.000000  4884.000000  4884.000000      4884.000000
# mean   9.545633e+06    55.725430    58.972973    61.555078       135.855446
# std    5.974547e+06    11.893245    11.247503    12.002715        33.488546
# min    1.971000e+03    14.000000    14.000000    13.000000        25.000000
# 25%    3.863223e+06    48.000000    51.000000    54.000000       111.000000
# 50%    1.008341e+07    56.000000    59.000000    62.000000       134.000000
# 75%    1.524365e+07    64.000000    67.000000    70.000000       161.000000
# max    1.810694e+07   109.000000   105.000000   103.000000       230.000000
#
#        Brightness_std
# count     4884.000000
# mean        57.741810
# std         11.025406
# min         14.000000
# 25%         50.000000
# 50%         58.000000
# 75%         65.000000
# max         98.000000

# %%
df_contrasts_brightness.to_csv('../../data/df_contrasts_brightness.csv', index=False)

# %% [markdown]
# ## Convert all pictures to greyscale array and reduce dimensionality

# %%
def load_image(infilename) :
    img = Image.open( infilename).convert(FORMAT)
    img = img.resize(SIZE, Image.ANTIALIAS) 
    img.load()
    data = np.asarray(img, dtype="int32" )
    
    #save_image(data)
    data = data.reshape(1,-1)
    return data

def reconstruct_image( npdata) :
    clipped_ndata = np.asarray(np.clip(npdata,0,255), dtype="uint8")  
    img = Image.fromarray(clipped_ndata, FORMAT )
    img.show()

# %%
def create_matrix_greyscale_pictures():
    all_pics =  [f for f in listdir('../../data/pictures') if isfile(join('../../data/pictures', f))]
    
    i=0
    for pic_file in all_pics:
        pic_id = pic_file.split('.')[0]
        try: 
            npdata = load_image('../../data/pictures/'+pic_file)
        except Exception as e:
            print "{0} for {1}".format(e,pic_file)
            continue
        npdata = np.append([pic_id],npdata)
        
        if i==0:
            
            npdata_all = npdata
            i=1
        else :
            npdata_all = np.vstack((npdata_all,npdata))
        
    return npdata_all

# %%
npdata_all = create_matrix_greyscale_pictures()
df_pictures = pd.DataFrame(npdata_all)
# Out:
# cannot identify image file '../../data/pictures/15959427.jpg' for 15959427.jpg
# cannot identify image file '../../data/pictures/16543634.jpg' for 16543634.jpg
# image file is truncated (0 bytes not processed) for 5284687.jpg

# %%
df_pictures.shape
# Out:
# (4884, 4097)

# %%
cols = ["pix_"+ str(i) for i in range(0,df_pictures.shape[1]-1)]

# %%
df_pictures.columns = ['listing_id']+ cols

# %%
df_pictures.to_csv('../../data/df_pictures_listing.csv')

# %% [markdown]
# ### Convert pictures array to PC

# %%
pca = PCA(n_components=50)

X_train = scale(df_pictures[cols].values)

X_transformed = pca.fit_transform(X_train)

df_pictures_PCA = pd.DataFrame(X_transformed)
df_pictures_PCA.columns = ['pictures_PC_'+str(i) for i in range(1,51)]
# Out:
# /home/ramon/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype object was converted to float64 by the scale function.
#   warnings.warn(msg, _DataConversionWarning)

# %%
df_pictures_PCA= pd.concat([df_pictures.listing_id,df_pictures_PCA],axis=1)

# %%
df_pictures.head()
# Out:
#   listing_id pix_0 pix_1 pix_2 pix_3 pix_4 pix_5 pix_6 pix_7 pix_8   ...     \
# 0    4725997    90    72    57    43    29    30    32    34    50   ...
# 1   16013696    34    35    36    35    37    43    31    20    36   ...
# 2    9379127   189   188   188   187   186   185   185   183   182   ...
# 3   14159874   100   109   121   118   127   136   134   106   114   ...
# 4   14195566   255   255   235   188   229   255   255   255   254   ...
#
#   pix_4086 pix_4087 pix_4088 pix_4089 pix_4090 pix_4091 pix_4092 pix_4093  \
# 0       47       43       30       37       61       86       99      103
# 1       47       51       54       54       62       44       90      132
# 2       10       10      151      128       16       40       50       53
# 3        2       26       33       30       32       16       19        8
# 4       38       30       49       57       53       40       48       49
#
#   pix_4094 pix_4095
# 0      106      108
# 1       39       53
# 2       51       24
# 3       28       26
# 4       49       52
#
# [5 rows x 4097 columns]

# %% [markdown]
# ## Extract top 5 colours in each pictures

# %%
NUM_CLUSTERS = 5

def extract_top_colour_in_picture(pic_file):
    
    pic_id = np.asarray([pic_file.split('.')[0]])
     
    
    im = Image.open('../../data/pictures/'+pic_file)
    im = im.resize((150, 150))      # optional, to reduce time
    ar = scipy.misc.fromimage(im)
    ar = ar.astype(float)
    shape = ar.shape
    ar = ar.reshape(scipy.product(shape[:2]), shape[2])

   
    codes, dist = scipy.cluster.vq.kmeans(ar, NUM_CLUSTERS)
    #print 'cluster centres:\n', codes

    vecs, dist = scipy.cluster.vq.vq(ar, codes)         # assign codes
    counts, bins = scipy.histogram(vecs, len(codes))    # count occurrences

    index_max = scipy.argmax(counts)                    # find most frequent
    peak = codes[index_max]
    
    

    peak = peak.astype(int)
    colour = ''.join(chr(c) for c in peak).encode('hex')
    #print 'most frequent is %s (#%s) \n' % (peak, colour)
    
    i=0
    
    for c in range (NUM_CLUSTERS):
        c_centroid=  np.asarray(codes[c])
        c_counts =  np.asarray([counts[c]])
        c_hex = ''.join(chr(c) for c in c_centroid.astype(int)).encode('hex')
        c_hex = np.asarray([c_hex])
        
        if i==0:
            npdata = np.concatenate((pic_id, c_centroid,c_counts,c_hex))#.astype('int32')
            i=1
        else :
            npdata = np.hstack((npdata,np.concatenate((c_centroid,c_counts,c_hex))))#.astype('int32')))
        
    return npdata

# %%
extract_top_colour_in_picture('81081.jpg')
# Out:
# array(['81081', '31.6452863962', '22.5784606205', '9.80071599045', '3322',
#        '1f1609', '159.360507246', '100.082729469', '22.1467391304', '1658',
#        '9f6416', '200.760361552', '181.243606702', '162.800485009', '4475',
#        'c8b5a2', '114.980956599', '92.7852081488', '88.1346324181', '2267',
#        '725c58', '226.319685923', '216.115442139', '208.327631333',
#        '10778', 'e2d8d0'],
#       dtype='|S32')

# %%
def create_colour_clusters_matrix():
    all_pics =  [f for f in listdir('../../data/pictures') if isfile(join('../../data/pictures', f))]
    
    i=0
    for pic_file in all_pics:
        
        try: 
            npdata = extract_top_colour_in_picture(pic_file)
        except Exception as e:
            print "{0} for {1}".format(e,pic_file)
            continue
        
        if i==0:
            
            npdata_all = npdata
            i=1
        else :
            npdata_all = np.vstack((npdata_all,npdata))
        
    return npdata_all

# %%
df_colors_cluster = pd.DataFrame(create_colour_clusters_matrix())
# Out:
# cannot identify image file '../../data/pictures/15959427.jpg' for 15959427.jpg
# cannot identify image file '../../data/pictures/16543634.jpg' for 16543634.jpg
# index 4 is out of bounds for axis 0 with size 4 for 16655645.jpg
# index 4 is out of bounds for axis 0 with size 4 for 14854731.jpg
# image file is truncated (0 bytes not processed) for 5284687.jpg

# %%
df_colors_cluster.shape
# Out:
# (4882, 26)

# %%
df_colors_cluster.head()
# Out:
#          0              1              2              3     4       5   \
# 0   4725997  141.703960015  144.572472126  138.253748558  5279  8d908a
# 1  16013696  246.606832098  245.868514341  249.586206897  3103  f6f5f9
# 2   9379127  202.747633216  194.681769002  185.733432513  7410  cac2b9
# 3  14159874  28.3095276479  27.9174592939  19.6803159761  6244  1c1b13
# 4  14195566  19.1839876828  23.6712856043  28.5681293303  2616  13171c
#
#               6              7              8     9    ...               16  \
# 0  214.950200089  240.074255225  248.261671854  4510   ...    47.3173852573
# 1  95.1568676822  82.3886440891  78.5413571698  7986   ...    53.4909971251
# 2    69.00514259  56.8728377747  35.0028050491  2118   ...    243.102139582
# 3  134.807058367  133.694589878  101.550901687  5014   ...         81.83408
# 4  106.288870924  118.415386688  119.656965777  7430   ...    229.982880536
#
#               17             18    19      20             21             22  \
# 0  43.6328233658  34.3418636996  3573  2f2b22  108.118238994  102.139622642
# 1  47.0118020881  46.4018762294  6530  352f2e   198.73357016   197.71107164
# 2  240.491085074  236.175751401  3948  f3f0ec  168.038702929  156.757147838
# 3        85.3752       64.94256  6398  515540  229.466666667  222.991515152
# 4  236.532192036  237.121324898  2673  e5eced  71.5329465396  83.0358474927
#
#               23    24      25
# 0   88.213836478  3891  6c6658
# 1  200.609236234  1689  c6c5c8
# 2   145.44735007  5703  a89c91
# 3  181.739090909  3273  e5deb5
# 4   76.409241608  4888  47534c
#
# [5 rows x 26 columns]

# %%
df_colors_cluster.columns = ['listing_id','Centroid_R_1','Centroid_G_1','Centroid_B_1','Centroid_Count_1','Centroid_hex_1',
                            'Centroid_R_2','Centroid_G_2','Centroid_B_2','Centroid_Count_2','Centroid_hex_2',
                          'Centroid_R_3','Centroid_G_3','Centroid_B_3','Centroid_Count_3','Centroid_hex_3',
                         'Centroid_R_4','Centroid_G_4','Centroid_B_4','Centroid_Count_4','Centroid_hex_4',
                           'Centroid_R_5','Centroid_G_5','Centroid_B_5','Centroid_Count_5','Centroid_hex_5']

# %%
cols_int = [col for col in df_colors_cluster.columns if 'hex' not in col]

# %%
df_colors_cluster[cols_int] = df_colors_cluster[cols_int].apply(pd.to_numeric)

# %%
df_colors_cluster.to_csv('../../data/df_colours_clusters.csv',index=False)

# %% [markdown]
# # Combine all (brightness/contrast, PCA of picture, colors clusters)

# %% [markdown]
# ## Select only new column

# %%
df_contrasts_brightness= df_contrasts_brightness[['listing_id',
 'R_contrast',
 'G_contrast',
 'B_contrast',
 'Brightness_mean',
 'Brightness_std']]

# %%
df_pictures_PCA.listing_id = pd.to_numeric(df_pictures_PCA.listing_id)
df_contrasts_brightness.listing_id = pd.to_numeric(df_contrasts_brightness.listing_id)
df_colors_cluster.listing_id = pd.to_numeric(df_colors_cluster.listing_id)

# %%
df_listing = pd.merge(df_listing[['listing_id']],df_pictures_PCA, on='listing_id')

# %%
df_listing.head()
# Out:
#    listing_id  pictures_PC_1  pictures_PC_2  pictures_PC_3  pictures_PC_4  \
# 0    16682014      44.891212      12.452659       6.974220      -5.184285
# 1    15767215     -13.490105     -12.614338      -2.372806       1.949370
# 2      115576      70.972239       5.991331       4.960066      -6.315522
# 3     7568544      18.405457       9.907819      32.082884       6.662087
# 4    16926322      45.456981      -9.009680       1.653136      -1.455836
#
#    pictures_PC_5  pictures_PC_6  pictures_PC_7  pictures_PC_8  pictures_PC_9  \
# 0      -6.731535       7.200861       0.510843       6.503110      -3.681690
# 1      11.773108     -16.377617       3.137355      -4.526477       3.566227
# 2      24.580115      -0.503351      -2.934977       4.063151       5.987481
# 3      -6.188300      -2.909725      -7.448552       6.885595       6.643106
# 4     -21.874762       1.806398      10.596269       2.150038       0.668536
#
#         ...        pictures_PC_41  pictures_PC_42  pictures_PC_43  \
# 0       ...              0.682334       -4.030088        3.763776
# 1       ...             -0.869935        0.591841        1.417125
# 2       ...              3.898138        0.664644        1.542807
# 3       ...             -2.307442       11.075362        1.057746
# 4       ...              0.196205       -0.733661       -6.514989
#
#    pictures_PC_44  pictures_PC_45  pictures_PC_46  pictures_PC_47  \
# 0       -1.164527        0.981281        2.797508       -1.978749
# 1        2.625522        4.016214       -0.275299       -1.638685
# 2       -1.076519       -3.881148        2.896477        2.806097
# 3        3.687718        6.816297       -6.136876        4.444175
# 4        0.235094        1.769292       -0.171437        1.263812
#
#    pictures_PC_48  pictures_PC_49  pictures_PC_50
# 0        1.575972        3.760916        2.553579
# 1       -8.802399       -1.819419        3.519856
# 2       -0.469314       -1.662616        1.910708
# 3       -0.225182       -4.886580        6.408059
# 4        1.044665       -1.200203       -0.555247
#
# [5 rows x 51 columns]

# %%
df_listing = pd.merge(df_listing,df_colors_cluster, on='listing_id')

# %%
df_listing.head()
# Out:
#    listing_id  pictures_PC_1  pictures_PC_2  pictures_PC_3  pictures_PC_4  \
# 0    16682014      44.891212      12.452659       6.974220      -5.184285
# 1    15767215     -13.490105     -12.614338      -2.372806       1.949370
# 2      115576      70.972239       5.991331       4.960066      -6.315522
# 3     7568544      18.405457       9.907819      32.082884       6.662087
# 4    16926322      45.456981      -9.009680       1.653136      -1.455836
#
#    pictures_PC_5  pictures_PC_6  pictures_PC_7  pictures_PC_8  pictures_PC_9  \
# 0      -6.731535       7.200861       0.510843       6.503110      -3.681690
# 1      11.773108     -16.377617       3.137355      -4.526477       3.566227
# 2      24.580115      -0.503351      -2.934977       4.063151       5.987481
# 3      -6.188300      -2.909725      -7.448552       6.885595       6.643106
# 4     -21.874762       1.806398      10.596269       2.150038       0.668536
#
#         ...        Centroid_R_4  Centroid_G_4  Centroid_B_4  Centroid_Count_4  \
# 0       ...          177.469172    132.889456     92.004013              2768
# 1       ...           33.548015     27.437394     22.637258              2949
# 2       ...          151.552294    139.262752    126.100917              2658
# 3       ...          101.476190     86.259857     63.597798              3864
# 4       ...           82.833176     48.248068     30.432422              5374
#
#    Centroid_hex_4  Centroid_R_5  Centroid_G_5  Centroid_B_5  Centroid_Count_5  \
# 0          b1845c    148.382132    101.487544     55.720868              7556
# 1          211b16    174.857235    154.274522    117.711881              3093
# 2          978b7e     42.008374     38.863547     35.771921              3886
# 3          65563f    213.969355    232.059677    233.895968              1246
# 4          52301e    130.570991     80.278447     50.572012              4887
#
#    Centroid_hex_5
# 0          946537
# 1          ae9a75
# 2          2a2623
# 3          d5e8e9
# 4          825032
#
# [5 rows x 76 columns]

# %%
df_listing = pd.merge(df_listing,df_contrasts_brightness, 
                      on='listing_id')

# %%
df_listing.head()
# Out:
#    listing_id  pictures_PC_1  pictures_PC_2  pictures_PC_3  pictures_PC_4  \
# 0    16682014      44.891212      12.452659       6.974220      -5.184285
# 1    15767215     -13.490105     -12.614338      -2.372806       1.949370
# 2      115576      70.972239       5.991331       4.960066      -6.315522
# 3     7568544      18.405457       9.907819      32.082884       6.662087
# 4    16926322      45.456981      -9.009680       1.653136      -1.455836
#
#    pictures_PC_5  pictures_PC_6  pictures_PC_7  pictures_PC_8  pictures_PC_9  \
# 0      -6.731535       7.200861       0.510843       6.503110      -3.681690
# 1      11.773108     -16.377617       3.137355      -4.526477       3.566227
# 2      24.580115      -0.503351      -2.934977       4.063151       5.987481
# 3      -6.188300      -2.909725      -7.448552       6.885595       6.643106
# 4     -21.874762       1.806398      10.596269       2.150038       0.668536
#
#         ...        Centroid_R_5  Centroid_G_5  Centroid_B_5  Centroid_Count_5  \
# 0       ...          148.382132    101.487544     55.720868              7556
# 1       ...          174.857235    154.274522    117.711881              3093
# 2       ...           42.008374     38.863547     35.771921              3886
# 3       ...          213.969355    232.059677    233.895968              1246
# 4       ...          130.570991     80.278447     50.572012              4887
#
#    Centroid_hex_5  R_contrast  G_contrast  B_contrast  Brightness_mean  \
# 0          946537          37          36          33               91
# 1          ae9a75          58          59          62              148
# 2          2a2623          64          63          61               69
# 3          d5e8e9          68          65          54              118
# 4          825032          51          51          55               88
#
#    Brightness_std
# 0              36
# 1              59
# 2              63
# 3              64
# 4              50
#
# [5 rows x 81 columns]

# %%
df_listing.to_csv('../../data/df_listing_active_with_pic.csv',index=False)

# %%
df_listing.shape
# Out:
# (4882, 81)
