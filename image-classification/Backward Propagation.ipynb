# %%
import numpy as np
from data_prep import features, targets, features_test, targets_test

np.random.seed(21)

def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1 / (1 + np.exp(-x))


# Hyperparameters
n_hidden = 2  # number of hidden units
epochs = 1
learnrate = 0.005

n_records, n_features = features.shape
last_loss = None
# Initialize weights
weights_input_hidden = np.random.normal(scale=1 / n_features ** .5,
                                        size=(n_features, n_hidden))
weights_hidden_output = np.random.normal(scale=1 / n_features ** .5,
                                         size=n_hidden)

for e in range(epochs):
    del_w_input_hidden = np.zeros(weights_input_hidden.shape)
    del_w_hidden_output = np.zeros(weights_hidden_output.shape)
    for x, y in zip(features.values, targets):
        ## Forward pass ##
        # TODO: Calculate the output
        hidden_input = np.dot(x, weights_input_hidden)
        hidden_output = sigmoid(hidden_input)

        output = sigmoid(np.dot(hidden_output,
                                weights_hidden_output))

        ## Backward pass ##
        # TODO: Calculate the network's prediction error
        error = y - output

        # TODO: Calculate error term for the output unit
        output_error_term = error * output * (1 - output)

        ## propagate errors to hidden layer

        # TODO: Calculate the hidden layer's contribution to the error
        hidden_error = np.dot(output_error_term, weights_hidden_output)

        # TODO: Calculate the error term for the hidden layer
        hidden_error_term = hidden_error * hidden_output * (1 - hidden_output)
        print ("Hidden error term")
        print (hidden_error_term)

        # TODO: Update the change in weights
        del_w_hidden_output += output_error_term * hidden_output
        del_w_input_hidden += hidden_error_term * x[:, None]

    # TODO: Update weights
    weights_input_hidden += learnrate * del_w_input_hidden / n_records
    weights_hidden_output += learnrate * del_w_hidden_output / n_records

    # Printing out the mean square error on the training set
    if e % (epochs / 10) == 0:
        hidden_output = sigmoid(np.dot(x, weights_input_hidden))
        out = sigmoid(np.dot(hidden_output,
                             weights_hidden_output))
        loss = np.mean((out - targets) ** 2)

        if last_loss and last_loss < loss:
            print("Train loss: ", loss, "  WARNING - Loss Increasing")
        else:
            print("Train loss: ", loss)
        last_loss = loss

# Calculate accuracy on test data
hidden = sigmoid(np.dot(features_test, weights_input_hidden))
out = sigmoid(np.dot(hidden, weights_hidden_output))
predictions = out > 0.5
accuracy = np.mean(predictions == targets_test)
print("Prediction accuracy: {:.3f}".format(accuracy))
# Out:
# Hidden error term
# [ 0.01584991 -0.00571042]
# Hidden error term
# [-0.02190618  0.00832587]
# Hidden error term
# [-0.0208851   0.00822482]
# Hidden error term
# [-0.01884156  0.00849975]
# Hidden error term
# [-0.02176179  0.00831819]
# Hidden error term
# [ 0.01895738 -0.00755309]
# Hidden error term
# [ 0.01854128 -0.0078278 ]
# Hidden error term
# [-0.02107187  0.00860685]
# Hidden error term
# [-0.02225045  0.00889924]
# Hidden error term
# [-0.02153686  0.00977768]
# Hidden error term
# [-0.02163167  0.00878926]
# Hidden error term
# [-0.02178181  0.00963263]
# Hidden error term
# [-0.02245807  0.0094737 ]
# Hidden error term
# [-0.02254482  0.00916859]
# Hidden error term
# [-0.02184245  0.00942828]
# Hidden error term
# [-0.02094578  0.00826961]
# Hidden error term
# [ 0.01739043 -0.00800912]
# Hidden error term
# [-0.02232989  0.00964109]
# Hidden error term
# [-0.02035998  0.0078518 ]
# Hidden error term
# [-0.02183586  0.00941861]
# Hidden error term
# [ 0.01855208 -0.00794887]
# Hidden error term
# [-0.02264422  0.00880728]
# Hidden error term
# [-0.02184574  0.00821697]
# Hidden error term
# [-0.01965187  0.00715773]
# Hidden error term
# [ 0.01923813 -0.00667645]
# Hidden error term
# [ 0.01522405 -0.00570826]
# Hidden error term
# [-0.02008008  0.00876412]
# Hidden error term
# [ 0.01693838 -0.00680691]
# Hidden error term
# [-0.01823678  0.00639733]
# Hidden error term
# [-0.02191039  0.00901083]
# Hidden error term
# [ 0.01890503 -0.00788811]
# Hidden error term
# [-0.01444924  0.00598734]
# Hidden error term
# [-0.01742054  0.00737187]
# Hidden error term
# [-0.02210591  0.00933432]
# Hidden error term
# [-0.02068614  0.00979454]
# Hidden error term
# [-0.0189085   0.00823206]
# Hidden error term
# [-0.01753878  0.00858711]
# Hidden error term
# [-0.02184397  0.00907091]
# Hidden error term
# [-0.022293    0.00898076]
# Hidden error term
# [-0.01545538  0.00649451]
# Hidden error term
# [-0.0214073   0.00930527]
# Hidden error term
# [-0.02256532  0.00930322]
# Hidden error term
# [-0.01747905  0.00851849]
# Hidden error term
# [ 0.01167231 -0.00554582]
# Hidden error term
# [-0.01954838  0.00936654]
# Hidden error term
# [-0.02132533  0.00845327]
# Hidden error term
# [-0.02214335  0.00938895]
# Hidden error term
# [ 0.01793636 -0.00763118]
# Hidden error term
# [-0.02148574  0.00979842]
# Hidden error term
# [-0.02216645  0.00926889]
# Hidden error term
# [-0.02253803  0.00931292]
# Hidden error term
# [-0.02175367  0.00976401]
# Hidden error term
# [ 0.01871603 -0.00816267]
# Hidden error term
# [-0.02201248  0.00858425]
# Hidden error term
# [-0.02038397  0.00889412]
# Hidden error term
# [-0.02109488  0.00921246]
# Hidden error term
# [-0.01732943  0.00717911]
# Hidden error term
# [ 0.01670398 -0.00674921]
# Hidden error term
# [-0.01953391  0.00849562]
# Hidden error term
# [-0.01724743  0.00870232]
# Hidden error term
# [-0.02207107  0.00970479]
# Hidden error term
# [ 0.01218716 -0.00396662]
# Hidden error term
# [-0.02247783  0.0094368 ]
# Hidden error term
# [-0.01670424  0.00574617]
# Hidden error term
# [-0.01945634  0.00768774]
# Hidden error term
# [-0.02122224  0.00913527]
# Hidden error term
# [-0.01977821  0.00944423]
# Hidden error term
# [-0.02091661  0.00984274]
# Hidden error term
# [-0.02259728  0.00919744]
# Hidden error term
# [-0.0218121   0.00941997]
# Hidden error term
# [-0.02210412  0.00967307]
# Hidden error term
# [-0.02207941  0.00827216]
# Hidden error term
# [-0.02231534  0.00952051]
# Hidden error term
# [-0.02234171  0.00958693]
# Hidden error term
# [ 0.01852479 -0.00792899]
# Hidden error term
# [ 0.01610815 -0.00742592]
# Hidden error term
# [-0.01815714  0.00866177]
# Hidden error term
# [-0.02154407  0.00979135]
# Hidden error term
# [-0.02051055  0.00972627]
# Hidden error term
# [-0.0208709   0.00915944]
# Hidden error term
# [-0.02121064  0.0096792 ]
# Hidden error term
# [ 0.01812311 -0.00672173]
# Hidden error term
# [ 0.01742473 -0.00706979]
# Hidden error term
# [-0.0212803  0.0092232]
# Hidden error term
# [-0.020796    0.00822067]
# Hidden error term
# [ 0.015601   -0.00592991]
# Hidden error term
# [-0.02253601  0.00939361]
# Hidden error term
# [ 0.01853406 -0.00793707]
# Hidden error term
# [-0.02201212  0.00972975]
# Hidden error term
# [ 0.01173718 -0.00549091]
# Hidden error term
# [-0.02045497  0.007715  ]
# Hidden error term
# [-0.02033867  0.00773511]
# Hidden error term
# [ 0.01832943 -0.0076397 ]
# Hidden error term
# [ 0.01856026 -0.00796772]
# Hidden error term
# [ 0.01868025 -0.00788888]
# Hidden error term
# [-0.01784838  0.00621355]
# Hidden error term
# [-0.01899593  0.00581922]
# Hidden error term
# [-0.01934436  0.00843465]
# Hidden error term
# [-0.01154384  0.00305991]
# Hidden error term
# [-0.02129257  0.00769221]
# Hidden error term
# [-0.02130421  0.0098032 ]
# Hidden error term
# [-0.02176749  0.0093958 ]
# Hidden error term
# [ 0.01534286 -0.00557154]
# Hidden error term
# [-0.01651137  0.00695011]
# Hidden error term
# [ 0.01528468 -0.00532724]
# Hidden error term
# [-0.02210596  0.00921679]
# Hidden error term
# [ 0.01749432 -0.00605804]
# Hidden error term
# [ 0.01882575 -0.00807433]
# Hidden error term
# [-0.02250622  0.00946712]
# Hidden error term
# [-0.02213397  0.0091231 ]
# Hidden error term
# [-0.02226299  0.00943672]
# Hidden error term
# [-0.02162717  0.00977996]
# Hidden error term
# [ 0.01377932 -0.00474955]
# Hidden error term
# [-0.02142176  0.00786607]
# Hidden error term
# [ 0.01565908 -0.0059926 ]
# Hidden error term
# [-0.01988957  0.00774554]
# Hidden error term
# [ 0.01553253 -0.00583402]
# Hidden error term
# [-0.01859298  0.00814318]
# Hidden error term
# [-0.02185138  0.00973801]
# Hidden error term
# [-0.01936119  0.00933038]
# Hidden error term
# [-0.02260301  0.00917488]
# Hidden error term
# [ 0.01542422 -0.00556318]
# Hidden error term
# [-0.02189434  0.00971381]
# Hidden error term
# [-0.0219392   0.00944522]
# Hidden error term
# [-0.02257414  0.00908806]
# Hidden error term
# [-0.02189205  0.00835342]
# Hidden error term
# [ 0.01558495 -0.00594866]
# Hidden error term
# [-0.02258778  0.0090936 ]
# Hidden error term
# [-0.01930402  0.0085694 ]
# Hidden error term
# [ 0.01867615 -0.00809923]
# Hidden error term
# [-0.02105568  0.00808136]
# Hidden error term
# [-0.02175388  0.00974327]
# Hidden error term
# [-0.02230735  0.00961135]
# Hidden error term
# [-0.02250964  0.00946632]
# Hidden error term
# [-0.0219171   0.00944018]
# Hidden error term
# [ 0.01831338 -0.00776675]
# Hidden error term
# [-0.02043175  0.00967498]
# Hidden error term
# [-0.01787311  0.00618761]
# Hidden error term
# [-0.02229089  0.00962013]
# Hidden error term
# [-0.02154824  0.00973981]
# Hidden error term
# [-0.02151047  0.00799265]
# Hidden error term
# [-0.01920159  0.00950272]
# Hidden error term
# [-0.02222087  0.00947871]
# Hidden error term
# [-0.02218959  0.00950104]
# Hidden error term
# [ 0.01872006 -0.00815945]
# Hidden error term
# [-0.02246778  0.00949448]
# Hidden error term
# [-0.02257292  0.00917782]
# Hidden error term
# [-0.01868424  0.00889392]
# Hidden error term
# [ 0.01686673 -0.00702692]
# Hidden error term
# [-0.02255222  0.00928512]
# Hidden error term
# [ 0.01465946 -0.00511241]
# Hidden error term
# [-0.01895275  0.00807378]
# Hidden error term
# [-0.01758795  0.0074916 ]
# Hidden error term
# [ 0.01778804 -0.00741453]
# Hidden error term
# [-0.01915786  0.00912589]
# Hidden error term
# [-0.01924851  0.00854404]
# Hidden error term
# [ 0.01612958 -0.00574811]
# Hidden error term
# [ 0.01825593 -0.0080335 ]
# Hidden error term
# [ 0.0190806  -0.00745579]
# Hidden error term
# [ 0.01874371 -0.00814028]
# Hidden error term
# [-0.02166878  0.00968261]
# Hidden error term
# [-0.02212908  0.00932838]
# Hidden error term
# [-0.02264103  0.00893615]
# Hidden error term
# [-0.01978748  0.00728547]
# Hidden error term
# [-0.02200354  0.00963505]
# Hidden error term
# [-0.01914551  0.00717459]
# Hidden error term
# [-0.02211707  0.00942225]
# Hidden error term
# [ 0.01867174 -0.008182  ]
# Hidden error term
# [ 0.0152038  -0.00515534]
# Hidden error term
# [-0.02021339  0.00957754]
# Hidden error term
# [ 0.01841601 -0.00805854]
# Hidden error term
# [ 0.01820668 -0.00770507]
# Hidden error term
# [-0.0221255   0.00928673]
# Hidden error term
# [-0.02137875  0.00816063]
# Hidden error term
# [ 0.01928712 -0.00672323]
# Hidden error term
# [-0.02250495  0.00900489]
# Hidden error term
# [-0.02136107  0.00980972]
# Hidden error term
# [ 0.01793418 -0.00748783]
# Hidden error term
# [ 0.01825901 -0.00814257]
# Hidden error term
# [-0.02151388  0.00889065]
# Hidden error term
# [ 0.01762355 -0.00722663]
# Hidden error term
# [ 0.01592316 -0.00728199]
# Hidden error term
# [ 0.01230682 -0.0061266 ]
# Hidden error term
# [-0.02007001  0.00637935]
# Hidden error term
# [ 0.01459354 -0.00479551]
# Hidden error term
# [ 0.01834153 -0.00781964]
# Hidden error term
# [ 0.01610649 -0.00623552]
# Hidden error term
# [-0.02076218  0.00969554]
# Hidden error term
# [-0.0222133   0.00948283]
# Hidden error term
# [ 0.01839158 -0.00777426]
# Hidden error term
# [-0.02145153  0.00848151]
# Hidden error term
# [-0.02067197  0.00884426]
# Hidden error term
# [-0.02246952  0.00937748]
# Hidden error term
# [-0.02197735  0.00865015]
# Hidden error term
# [ 0.01561297 -0.00573762]
# Hidden error term
# [ 0.01834544 -0.00777968]
# Hidden error term
# [-0.02242282  0.00947631]
# Hidden error term
# [-0.02236141  0.00952376]
# Hidden error term
# [-0.01783815  0.00592712]
# Hidden error term
# [ 0.01774879 -0.00766375]
# Hidden error term
# [-0.02263707  0.00882921]
# Hidden error term
# [-0.01761071  0.00841029]
# Hidden error term
# [-0.02211819  0.0083119 ]
# Hidden error term
# [ 0.01249634 -0.00369981]
# Hidden error term
# [ 0.01510274 -0.00584166]
# Hidden error term
# [ 0.0187158  -0.00815953]
# Hidden error term
# [ 0.01229763 -0.00387058]
# Hidden error term
# [-0.02043046  0.00901757]
# Hidden error term
# [-0.01981953  0.00857719]
# Hidden error term
# [ 0.01197636 -0.00585237]
# Hidden error term
# [-0.02009396  0.00777452]
# Hidden error term
# [ 0.01846681 -0.00786748]
# Hidden error term
# [ 0.01908246 -0.00712007]
# Hidden error term
# [-0.02252261  0.00907758]
# Hidden error term
# [-0.02175359  0.00972663]
# Hidden error term
# [-0.01669047  0.00692703]
# Hidden error term
# [ 0.01674235 -0.00752703]
# Hidden error term
# [-0.02088029  0.00743197]
# Hidden error term
# [ 0.01562888 -0.00571813]
# Hidden error term
# [-0.02249739  0.00939363]
# Hidden error term
# [-0.01670424  0.00574617]
# Hidden error term
# [-0.01933264  0.00710223]
# Hidden error term
# [-0.02204943  0.00916599]
# Hidden error term
# [ 0.01828209 -0.00779575]
# Hidden error term
# [ 0.01842495 -0.00823045]
# Hidden error term
# [-0.02189655  0.00972881]
# Hidden error term
# [-0.02120378  0.00699524]
# Hidden error term
# [-0.02245533  0.00949139]
# Hidden error term
# [ 0.0124522  -0.00373751]
# Hidden error term
# [ 0.01622118 -0.00617518]
# Hidden error term
# [-0.02138133  0.00977697]
# Hidden error term
# [-0.02004445  0.00955219]
# Hidden error term
# [-0.01801137  0.00790077]
# Hidden error term
# [-0.01727233  0.00736955]
# Hidden error term
# [ 0.01705848 -0.00671009]
# Hidden error term
# [ 0.01238598 -0.00379433]
# Hidden error term
# [-0.019023    0.00903657]
# Hidden error term
# [-0.02223502  0.00950876]
# Hidden error term
# [ 0.01506003 -0.00558586]
# Hidden error term
# [-0.02055522  0.0088508 ]
# Hidden error term
# [-0.02186022  0.00839191]
# Hidden error term
# [-0.0219444   0.00973853]
# Hidden error term
# [-0.02224763  0.00866206]
# Hidden error term
# [-0.02088954  0.00848526]
# Hidden error term
# [-0.02254784  0.0093678 ]
# Hidden error term
# [-0.02046072  0.00874101]
# Hidden error term
# [-0.02045787  0.00966229]
# Hidden error term
# [-0.02180366  0.00836577]
# Hidden error term
# [-0.02078473  0.00975951]
# Hidden error term
# [ 0.01869605 -0.00805261]
# Hidden error term
# [-0.01958754  0.0092602 ]
# Hidden error term
# [-0.02185915  0.00966179]
# Hidden error term
# [-0.02218678  0.00950069]
# Hidden error term
# [ 0.01505814 -0.00704291]
# Hidden error term
# [-0.02260692  0.00886472]
# Hidden error term
# [-0.02186602  0.00832873]
# Hidden error term
# [-0.02153961  0.00884619]
# Hidden error term
# [-0.02226458  0.00880004]
# Hidden error term
# [-0.02198802  0.00971046]
# Hidden error term
# [ 0.01419435 -0.00682507]
# Hidden error term
# [-0.02206289  0.00885327]
# Hidden error term
# [ 0.01532604 -0.00559125]
# Hidden error term
# [-0.02260746  0.0091272 ]
# Hidden error term
# [-0.01764354  0.00838291]
# Hidden error term
# [-0.02175239  0.00976791]
# Hidden error term
# [-0.02244289  0.00944281]
# Hidden error term
# [ 0.01702962 -0.00661963]
# Hidden error term
# [-0.02027478  0.0098138 ]
# Hidden error term
# [ 0.01865115 -0.00803115]
# Hidden error term
# [-0.02249162  0.00945711]
# Hidden error term
# [-0.02257292  0.00917782]
# Hidden error term
# [ 0.01852241 -0.00820643]
# Hidden error term
# [-0.02119427  0.00751813]
# Hidden error term
# [-0.02206998  0.00952408]
# Hidden error term
# [ 0.01145654 -0.00583175]
# Hidden error term
# [-0.02126568  0.00829744]
# Hidden error term
# [-0.02206683  0.0094706 ]
# Hidden error term
# [-0.02233981  0.00952715]
# Hidden error term
# [-0.02084757  0.00733038]
# Hidden error term
# [ 0.01197636 -0.00585237]
# Hidden error term
# [-0.02208563  0.00912855]
# Hidden error term
# [ 0.01875977 -0.00811572]
# Hidden error term
# [ 0.01837428 -0.00779257]
# Hidden error term
# [ 0.01883816 -0.00727953]
# Hidden error term
# [ 0.01824444 -0.0077239 ]
# Hidden error term
# [-0.02042407  0.00894764]
# Hidden error term
# [-0.02124226  0.00846763]
# Hidden error term
# [ 0.01676849 -0.00678843]
# Hidden error term
# [ 0.01630152 -0.00650732]
# Hidden error term
# [-0.02208359  0.00947332]
# Hidden error term
# [-0.0216171   0.00882112]
# Hidden error term
# [ 0.01345713 -0.00630211]
# Hidden error term
# [-0.01940748  0.00581605]
# Hidden error term
# [ 0.01466403 -0.00695525]
# Hidden error term
# [ 0.0145304  -0.00701662]
# Hidden error term
# [-0.02165115  0.00970445]
# Hidden error term
# [ 0.01799044 -0.00742926]
# Hidden error term
# [ 0.01611005 -0.00736394]
# Hidden error term
# [-0.02254671  0.00936678]
# Hidden error term
# [-0.02090561  0.00907585]
# Hidden error term
# [-0.0226061   0.00896351]
# Hidden error term
# [-0.01763739  0.00850732]
# Hidden error term
# [ 0.01828101 -0.0077367 ]
# Hidden error term
# [ 0.01836304 -0.00784409]
# Hidden error term
# [-0.02164544  0.00977915]
# Hidden error term
# [-0.01893439  0.00587952]
# Hidden error term
# [-0.02246102  0.00944507]
# Hidden error term
# [ 0.01815139 -0.00778547]
# Hidden error term
# [-0.01734688  0.00862444]
# Hidden error term
# [-0.02247351  0.0094669 ]
# Hidden error term
# [ 0.01446433 -0.00683357]
# Hidden error term
# [-0.01863367  0.00671101]
# Hidden error term
# [-0.02132753  0.00858745]
# Hidden error term
# [-0.02142314  0.00810507]
# Hidden error term
# [ 0.01795374 -0.00743874]
# Hidden error term
# [-0.02222026  0.0094917 ]
# Hidden error term
# [ 0.01889753 -0.00790923]
# Hidden error term
# [-0.01855002  0.00867926]
# Hidden error term
# [-0.02201237  0.00954983]
# Hidden error term
# [-0.02250892  0.00880979]
# Hidden error term
# [-0.02140574  0.00791252]
# Hidden error term
# [ 0.01833067 -0.00818254]
# Hidden error term
# [ 0.01539295 -0.00577799]
# Hidden error term
# [-0.02212228  0.00795708]
# Hidden error term
# [-0.02196343  0.00961841]
# Hidden error term
# [-0.02137155  0.00980418]
# Hidden error term
# [-0.01737997  0.00859817]
# Hidden error term
# [-0.02094783  0.00904608]
# Hidden error term
# [ 0.01591631 -0.00589764]
# Hidden error term
# [-0.02186162  0.00952908]
# Hidden error term
# [-0.02177605  0.00829922]
# Hidden error term
# [-0.01786579  0.00888746]
# Hidden error term
# [-0.02244828  0.00941365]
# Hidden error term
# [ 0.016627   -0.00751231]
# Hidden error term
# [ 0.01173718 -0.00549091]
# Hidden error term
# [-0.01802754  0.00587518]
# Hidden error term
# [ 0.01717165 -0.00719938]
# Hidden error term
# [-0.01859182  0.00660732]
# Hidden error term
# [-0.02215831  0.00970439]
# Hidden error term
# [-0.01840812  0.00899958]
# Hidden error term
# [ 0.01291574 -0.00619023]
# Hidden error term
# [-0.02200633  0.00860031]
# Hidden error term
# [-0.02086233  0.00910327]
# Hidden error term
# [-0.02246985  0.00948557]
# Hidden error term
# [-0.02206992  0.0094606 ]
# Hidden error term
# [-0.02075425  0.00828098]
# Hidden error term
# [-0.02068192  0.00810902]
# Hidden error term
# [-0.02212358  0.00948061]
# Hidden error term
# [ 0.01783294 -0.00708488]
# Hidden error term
# [-0.02200243  0.00945641]
# Hidden error term
# [ 0.01490185 -0.00497458]
# Hidden error term
# [-0.02027466  0.00888704]
# Hidden error term
# [-0.01981405  0.00634436]
# Hidden error term
# [ 0.01370423 -0.00652008]
# Hidden error term
# [-0.01757785  0.00843754]
# Hidden error term
# [ 0.0186465  -0.00816294]
# Hidden error term
# [-0.02204021  0.00946469]
# Hidden error term
# [-0.02183251  0.00970218]
# Hidden error term
# [-0.02257836  0.00926214]
# Hidden error term
# [-0.01797251  0.007545  ]
# Train loss:  0.25135725242598617
# Prediction accuracy: 0.450
